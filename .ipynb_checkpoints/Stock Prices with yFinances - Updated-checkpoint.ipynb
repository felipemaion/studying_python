# %%
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('PETR4.SA','2019-03-03','2020-03-03')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
data['Adj Close'].plot()
plt.show()

# %% [markdown]
# Tá vendo que preciso colocar .SA no código do ativo? Para o yhoo pegar aqui do South America..
#
# entao... mais como da pra pegar todos os ticker existente?

# %%
data.head()
total_data = {}

# %%
ativos = ["ABCB4", "ABEV3", "AMZO34", "ANIM3", "ARZZ3", "B3SA3", "BBAS3", "BBDC4", "BBFI11B", "BIDI4", "BRCR11", "BRFS3", "BRPR3", "BTOW3", "CIEL3", "COCE5", "CPTS11B", "CSAN3", "CVCB3", "CYRE3", "DMMO11", "DRIT11B", "EGIE3", "ELET6", "EVEN3", "EZTC3", "FAED11", "FAMB11B", "FEXC11", "FIGS11", "FIIP11B", "FLRY3", "GGRC11", "GNDI3", "GRND3", "HCRI11", "HGBS11", "HGLG11", "HGRE11", "HGTX3", "IRBR3", "ITSA3", "ITSA4", "ITUB3", "JHSF3", "JSLG3", "KEPL3", "KLBN4", "KNCR11", "KNIP11", "KNRI11", "LCAM3", "LEVE3", "LREN3", "MALL11", "MBRF11", "MELI34", "MFII11", "MGLU3", "MOVI3", "MRVE3", "MXRF11", "PETR3", "PETR4", "PORD11", "PRIO3", "PTBL3", "RADL3", "RBBV11", "RBCB11", "RBGS11", "RBRF11", "RCRB11", "RENT3", "RNGO11", "SAPR4", "SDIL11", "SGPS3", "SLCE3", "SMAL11", "SPTW11", "SQIA3", "TAEE11", "TEND3", "TIET11", "TRPL4", "TUPY3", "UNIP6", "VIVA3", "VVAR3", "WEGE3", "XPCM11", "XPLG11", "XPML11", "DIVO11", "IVVB11", "AMAR3"]

# ativos = ["SQIA3", "PNVL3", "STBP3", "BEEF3", "ALSO3", "LCAM3","JPSA3", "HBOR3"]

ativos = [ativo + ".SA" for ativo in ativos]

# %%
recomprando = ["EZTC3","EVEN3","ANIM3","ARZZ3","B3SA3","BIDI4","BRFS3","CSAN3","CYRE3","MRVE3","TUPY3","HGTX3","BTOW3","CIEL3","GNDI3","PTBL3"]

# %%
try:
    data = yf.download(ativos,'2019-02-12','2020-04-28')
    total_data[ativo] = data
    print(ativo, data['Adj Close'][0], data['Adj Close'][-1])
except:
    continue

# %%
# ativos2 = ["RCRB11"]
for ativo in ativos:
    try:
        data = yf.download(ativo,'2018-02-12','2020-04-28')
        total_data[ativo] = data
        print(ativo, data['Adj Close'][0], data['Adj Close'][-1])
    except:
        continue

# %%
total_data

# %%
total_data['ABCB4.SA']

# %%
total_data['ABCB4.SA']['Adj Close'].plot()

# %%
total_data['ABCB4.SA'].loc['2019-03-04']

# %%
the_ones = ["LCAM3","LEVE3","MGLU3","TAEE11","TRPL4","GRLV11","KNIP11","XPML11","ITSA4","ITUB3","RNGO11","HGRE11"]

# %%
the_ones.sort()

# %%
the_ones

# %%
len(the_ones)

# %%
100/12

# %%
from pylab import *
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [50, 50]
plt.rcParams.update({'font.size': 30})

for i, ativo in enumerate(ativos[:12]):
    subplot(4,3,i+1)
    title(ativo)
    xticks(rotation=90)
    plot(total_data[ativo]['Adj Close'])

show()

# %% [markdown]
# <h1>TO DO:</H1>
# <ul>
#     <li> Colocar Mouse Hover nos gráficos com Bokeh

# %%
import yfinance as yf
data = yf.download("MGLU3" + '.SA','2017-08-16')

# %%
data

# %% [markdown]
# Viu aqui eu pego todas as infos sobre os preços do ativo...

# %% [markdown]
# entendi, mais como que ele pegou todos os ativos existentes e images?
#
# as imagens ele gerou com os dados dos preços. Os ativos eu peguei pelo código.
# sim to falando do baster ele nao fez 1 a 1.
# Cara, talvez ele tenha feito sim... ahahah mas não que precise...
# aqui eu não pego via baster...

# %% [markdown]
# da para pegar via bmf, via google, via yahoo (q é esse caso...)
# eu entendo q conforme o usuário adicione o ativo/ação, aí sim ele vai começar a buscar..
#
# humm entendi, entao..... de comeco vc nao vai verificar se existe o ticker? bhahaha é com r.

# %% [markdown]
# humm eu acho q consigo uma lista de todos os códigos de ativos da bolsa... mas não sei... será?
# acha que é util? ser assim ou permite o usuario colocar qualquer coisa ? o baster permite isso ?
# Em ações acho q não. Só os q já existem...
# Em BDRs (que tb são negociadas na bolsa) sei q dá para colocar, coloquei o da AMZO34 que ele não achava... fui no forum avisei, e passou a achar e atualizar.
# ah  entao tem que ter uma equipe por traz
# não sei pq... pq o yahoo finances pega o dado do mesmo jeito ahhaha
# que fonte é essa o.O

# %%
import xlwings as xw

# %%
import xlwings as xw
current = xw.apps.keys()
wb = xw.apps[current[0]].books[0]

# %%
wb = xw.apps[current[0]].books[0]

# %%
sht = wb.sheets['CARTEIRA ELEVEN']

# %%
ativos = sht.range('B40:B72').value

# %%
# ativos.remove('SELIC.SA')
ativos

# %%
datas = sht.range('C39:M39').value

# %%
datas

# %%
data = yf.download(ativos,datas[0])

# %%
data["Adj Close"]

# %%
sht2 = wb.sheets['HistPrecosEleven']

# %%
sht2.range('A1').value = data['Adj Close']

# %%
#!/usr/bin/env python

import requests 
from bs4 import BeautifulSoup
import json
import re


def striphtml(data):
    p = re.compile(r'<.*?>')
    return p.sub('', data)

class DataCompany():
    def __init__(self, name):
        self.name = name
        self.url = "https://www.investsite.com.br/principais_indicadores.php?cod_negociacao={}".format(self.name)
        self.site = requests.get(self.url)
        self.items = []
        self.data = {}
        self.display_keys = {}
        self.keys = []
        self.json_data = {}
        self.getdata()

    def getdata(self):
        self.keys = []
        soup = BeautifulSoup(self.site.text, "html.parser")
        div = soup.find(id="mostradados_empresa")
        if not div: return {}
        tables_list = div.find_all("table")
        # for c in range(len(tables_list)):
        for table in tables_list:
            lists = table.find_all("td")
            for lis in lists:
                try:
                    self.items.append(lis.contents[0])
                except:
                    self.items.append('-')
            contx = 0
            conty = 1
            while True:
            
                if conty >= len(self.items):
                    break
                else:
                    key, value = self.items[contx], striphtml(str(self.items[conty]))
                    new_key = self.clean_key(key)
                    print("{}:{}".format(new_key, value))
                    self.display_keys[new_key] = key
                    self.keys.append(new_key)
                    self.data[new_key] = value                          
                    contx += 2
                    conty += 2
            self.items = []
        self.data["url"] = self.url    
        data = {"data":self.data, "display":self.display_keys}    
        self.json_data = json.dumps(data, ensure_ascii=False).encode("utf8").decode() 

    def clean_key(self, key):
        new_key = self.clean_string(key)
        return new_key

    def to_camel_case(self, key):
        words = key.split(' ')
        return words[0].lower() + ''.join(x.title() for x in words[1:])


    def clean_string(self, key):
        key = key.replace(".","").replace("s/","Sobre").replace("(","").replace(")","").replace("/"," ")
        translationTable = str.maketrans("éàèùâêîôûçõóíãáúü"+"éàèùâêîôûçõóíãáúü".upper(), "eaeuaeioucooiaauu"+"eaeuaeioucooiaauu".upper())
        key = key.translate(translationTable)
        return self.to_camel_case(key)

class Company(DataCompany):
    def __init__(self, name):
        super(Company,self).__init__(name)
        self.getdata()
    def __str__(self):
        return str(self.data)
       
        

                
# if __name__ == "__main__":
#     wege = Company("WEGE3")
#     klbn = Company("KLBN4")
#     amar = Company("AMAR3")

# %%
import yfinance as yf
import xlwings as xw
import schedule
import time
from datetime import datetime 
from IPython.display import clear_output
import pandas as pd
from pandas import json_normalize  

assets = []

def get_assets():
    print("Getting Assets")
    assets = []
    current = xw.apps.keys()
    print(current)
    wb = xw.apps[current[0]].books[0] 
    sht_assets = wb.sheets['ATIVOS']
    active = True
    i = 2
    print(f"Starts assets:{datetime.now()}")
    # Enquanto houver assets na coluna A
    while active:
        asset = sht_assets.range(f"A{i}").value
        assets.append(asset)
        if asset is None: 
            active = False
            break
        i = i + 1
    print(f"Ends assets:{datetime.now()}")  
    return assets
    
    
def populate_prices():
    assets = get_assets()
#     print(assets)
    print(f"Starts Prices:{datetime.now()}")
    current = xw.apps.keys()
    wb = xw.apps[current[0]].books[0] 
    sht_assets = wb.sheets['ATIVOS']
        # Pega último preço do Ativo
    for i, asset in enumerate(assets, start = 2):
        try:
            yf_asset = yf.Ticker(f"{asset}.SA").history().tail(1)['Close'].iloc[0]
            if asset == "SELIC": yf_asset = 1
            sht_assets.range(f"D{i}").value = yf_asset
#             print(f"\tAtivo: {asset} -> R$ {yf_asset}")
            
        except Exception as e:
            print(f"Erro: { asset } - {e}")
            pass
        
    print(f"Ends Prices:{datetime.now()}")    
#     return schedule.CancelJob



def populate_fundamentos():
    assets = get_assets()
    print(f"Starts Fundamentos:{datetime.now()}")
    load_Company = Company(assets[0])
    total_DataFrame = json_normalize(json.loads(load_Company.json_data)['data'])

    for asset in assets[1:]:
        load_Company = Company(asset)
        if load_Company.data:
            load_DataFrame = json_normalize(json.loads(load_Company.json_data)['data'])
            total_DataFrame = pd.concat([total_DataFrame,load_DataFrame],sort=True, ignore_index=True).dropna(thresh=2)
    print(f"Ends Fundamentos:{datetime.now()}")
    current = xw.apps.keys()
    wb = xw.apps[current[0]].books[0] 
    sht_fundamentos = wb.sheets['FUNDAMENTOS']
    sht_fundamentos.range(f"A1").value = total_DataFrame
    
    return total_DataFrame
    
    
populate_prices()    
total_DataFrame = populate_fundamentos()
total_DataFrame.to_excel("output20201019.xlsx")
# print(f"Starts schedulling:{datetime.now()}")
# schedule.every(15).minutes.do(populate_prices)
# schedule.every(30).minutes.do(populate_fundamentos)
# while 1:
# #     clear_output()
#     schedule.run_pending()
#     time.sleep(1)
# Out:
# Getting Assets
# [14821]
# Starts assets:2020-10-19 15:27:17.142448
# Ends assets:2020-10-19 15:27:18.214421
# Starts Prices:2020-10-19 15:27:18.214560
# - DMMO11.SA: No data found for this date range, symbol may be delisted
# Erro: DMMO11 - single positional indexer is out-of-bounds
# - NONE.SA: No data found, symbol may be delisted
# Erro: None - single positional indexer is out-of-bounds
# Ends Prices:2020-10-19 15:32:15.021029
# Getting Assets
# [14821]
# Starts assets:2020-10-19 15:32:15.486611
# Ends assets:2020-10-19 15:32:16.525743
# Starts Fundamentos:2020-10-19 15:32:16.525887
# empresa:ABC BRASIL
# razaoSocial:BCO ABC BRASIL S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 2 de Governança Corporativa
# atividade:O Banco Tem Por Objeto A Prática de Operações Ativas. Passivas E Acessórias Inerentes às Respectivas Carteiras Autorizadas Pelo Banco Central Do Brasil.
# acao:ABCB4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 12,65
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 9,08 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBRA
# precoLucro:7,12
# precoVpa:0,67
# precoReceitaLiquida:0,42
# precoFco:-2,02
# precoAtivoTotal:0,06
# recIntermFinanc:R$ 6,35 B
# resBrutoIntermFinanc:- R$ 15,87 M
# recPrestServ:R$ 294,17 M
# lucroLiquido:R$ 387,73 M
# recIntermFinanc:R$ 1,54 B
# resBrutoIntermFinanc:- R$ 19,85 M
# recPrestServ:R$ 60,77 M
# lucroLiquido:R$ 61,62 M
# menorPreco52Sem:R$ 10,90
# maiorPreco52Sem:R$ 23,48
# variacao2020:-36,97%
# variacao1Ano:-28,34%
# variacao2AnosTotal:-8,28%
# variacao2AnosAnual:-4,24%
# variacao3AnosTotal:-17,05%
# variacao3AnosAnual:-6,05%
# variacao4AnosTotal:9,04%
# variacao4AnosAnual:2,19%
# variacao5AnosTotal:102,33%
# variacao5AnosAnual:15,12%
# volumeDiarioMedio3Meses:R$ 10,55 M
# retornoSobrePatrimonioLiquido:9,72%
# retornoSobreAtivo:0,91%
# margemBruta:4,19%
# margemLiquida:5,84%
# dividendYield:5,14%
# giroDoAtivo:0,16
# alavancagemFinanceira:10,63
# passivoPatrimonioLiquido:9,63
# marketCap:R$ 1,38 B
# lucroAcao:R$ 1,78
# valorPatrimonialDaAcao:R$ 18,75
# ativoTotal:R$ 49,90 B
# patrimonioLiquido:R$ 4,09 B
# quantAcoesOrdinarias:109.496.432
# quantAcoesPreferenciais:108.862.625
# quantAcoesTotais:218.359.057
# empresa:ABC BRASIL
# razaoSocial:BCO ABC BRASIL S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 2 de Governança Corporativa
# atividade:O Banco Tem Por Objeto A Prática de Operações Ativas. Passivas E Acessórias Inerentes às Respectivas Carteiras Autorizadas Pelo Banco Central Do Brasil.
# acao:ABCB4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 12,65
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 9,08 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBRA
# precoLucro:7,12
# precoVpa:0,67
# precoReceitaLiquida:0,42
# precoFco:-2,02
# precoAtivoTotal:0,06
# recIntermFinanc:R$ 6,35 B
# resBrutoIntermFinanc:- R$ 15,87 M
# recPrestServ:R$ 294,17 M
# lucroLiquido:R$ 387,73 M
# recIntermFinanc:R$ 1,54 B
# resBrutoIntermFinanc:- R$ 19,85 M
# recPrestServ:R$ 60,77 M
# lucroLiquido:R$ 61,62 M
# menorPreco52Sem:R$ 10,90
# maiorPreco52Sem:R$ 23,48
# variacao2020:-36,97%
# variacao1Ano:-28,34%
# variacao2AnosTotal:-8,28%
# variacao2AnosAnual:-4,24%
# variacao3AnosTotal:-17,05%
# variacao3AnosAnual:-6,05%
# variacao4AnosTotal:9,04%
# variacao4AnosAnual:2,19%
# variacao5AnosTotal:102,33%
# variacao5AnosAnual:15,12%
# volumeDiarioMedio3Meses:R$ 10,55 M
# retornoSobrePatrimonioLiquido:9,72%
# retornoSobreAtivo:0,91%
# margemBruta:4,19%
# margemLiquida:5,84%
# dividendYield:5,14%
# giroDoAtivo:0,16
# alavancagemFinanceira:10,63
# passivoPatrimonioLiquido:9,63
# marketCap:R$ 1,38 B
# lucroAcao:R$ 1,78
# valorPatrimonialDaAcao:R$ 18,75
# ativoTotal:R$ 49,90 B
# patrimonioLiquido:R$ 4,09 B
# quantAcoesOrdinarias:109.496.432
# quantAcoesPreferenciais:108.862.625
# quantAcoesTotais:218.359.057
# empresa:AMBEV S/A
# razaoSocial:AMBEV S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Tradicional - BOVESPA
# atividade:Fabricação E Distribuição de Cervejas. Refrigerantes E Bebidas Não Carbonatadas E Não Alcoólicas.
# acao:ABEV3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 13,27
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 350,02 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo não Cíclico
# subsetor:Bebidas
# segmento:Cervejas e Refrigerantes
# partIndices:IBOVESPA
# precoLucro:22,44
# precoVpa:2,76
# precoReceitaLiquida:4,01
# precoFco:12,60
# precoFcf:19,01
# precoAtivoTotal:1,72
# precoEbit:15,60
# precoCapitalGiro:29,71
# precoNcav:-21,77
# evEbit:14,80
# evEbitda:10,86
# evReceitaLiquida:3,81
# evFco:11,96
# evFcf:18,03
# evAtivoTotal:1,63
# receitaLiquida:R$ 52,03 B
# resultadoBruto:R$ 28,98 B
# ebit:R$ 13,38 B
# depreAmort:R$ 4,86 B
# ebitda:R$ 18,24 B
# lucroLiquido:R$ 9,31 B
# receitaLiquida:R$ 11,62 B
# resultadoBruto:R$ 5,81 B
# ebit:R$ 1,90 B
# lucroLiquido:R$ 1,27 B
# menorPreco52Sem:R$ 11,03
# maiorPreco52Sem:R$ 19,22
# variacao2020:-30,89%
# variacao1Ano:-27,06%
# variacao2AnosTotal:-16,52%
# variacao2AnosAnual:-8,65%
# variacao3AnosTotal:-34,46%
# variacao3AnosAnual:-13,15%
# variacao4AnosTotal:-24,77%
# variacao4AnosAnual:-6,87%
# variacao5AnosTotal:-21,66%
# variacao5AnosAnual:-4,76%
# volumeDiarioMedio3Meses:R$ 399,82 M
# retornoSobreCapitalTangivel:49,14%
# retornoSobreCapitalInvestido:17,82%
# retornoSobrePatrimonioLiquido:13,44%
# retornoSobreAtivo:8,45%
# margemBruta:55,69%
# margemLiquida:17,88%
# margemEbit:25,72%
# dividendYield:3,70%
# giroDoAtivo:0,47
# alavancagemFinanceira:1,59
# passivoPatrimonioLiquido:0,59
# marketCap:R$ 208,81 B
# enterpriseValue:R$ 198,10 B
# lucroAcao:R$ 0,59
# valorPatrimonialDaAcao:R$ 4,80
# disponibilidades:R$ 17,48 B
# ativoTotal:R$ 121,39 B
# dividaCp:R$ 4,12 B
# dividaLp:R$ 2,66 B
# dividaBruta:R$ 6,78 B
# dividaLiquida:- R$ 10,70 B
# patrimonioLiquido:R$ 75,53 B
# quantAcoesOrdinarias:15.735.117.965
# quantAcoesPreferenciais:0
# quantAcoesTotais:15.735.117.965
# empresa:AMBEV S/A
# razaoSocial:AMBEV S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Tradicional - BOVESPA
# atividade:Fabricação E Distribuição de Cervejas. Refrigerantes E Bebidas Não Carbonatadas E Não Alcoólicas.
# acao:ABEV3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 13,27
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 350,02 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo não Cíclico
# subsetor:Bebidas
# segmento:Cervejas e Refrigerantes
# partIndices:IBOVESPA
# precoLucro:22,44
# precoVpa:2,76
# precoReceitaLiquida:4,01
# precoFco:12,60
# precoFcf:19,01
# precoAtivoTotal:1,72
# precoEbit:15,60
# precoCapitalGiro:29,71
# precoNcav:-21,77
# evEbit:14,80
# evEbitda:10,86
# evReceitaLiquida:3,81
# evFco:11,96
# evFcf:18,03
# evAtivoTotal:1,63
# receitaLiquida:R$ 52,03 B
# resultadoBruto:R$ 28,98 B
# ebit:R$ 13,38 B
# depreAmort:R$ 4,86 B
# ebitda:R$ 18,24 B
# lucroLiquido:R$ 9,31 B
# receitaLiquida:R$ 11,62 B
# resultadoBruto:R$ 5,81 B
# ebit:R$ 1,90 B
# lucroLiquido:R$ 1,27 B
# menorPreco52Sem:R$ 11,03
# maiorPreco52Sem:R$ 19,22
# variacao2020:-30,89%
# variacao1Ano:-27,06%
# variacao2AnosTotal:-16,52%
# variacao2AnosAnual:-8,65%
# variacao3AnosTotal:-34,46%
# variacao3AnosAnual:-13,15%
# variacao4AnosTotal:-24,77%
# variacao4AnosAnual:-6,87%
# variacao5AnosTotal:-21,66%
# variacao5AnosAnual:-4,76%
# volumeDiarioMedio3Meses:R$ 399,82 M
# retornoSobreCapitalTangivel:49,14%
# retornoSobreCapitalInvestido:17,82%
# retornoSobrePatrimonioLiquido:13,44%
# retornoSobreAtivo:8,45%
# margemBruta:55,69%
# margemLiquida:17,88%
# margemEbit:25,72%
# dividendYield:3,70%
# giroDoAtivo:0,47
# alavancagemFinanceira:1,59
# passivoPatrimonioLiquido:0,59
# marketCap:R$ 208,81 B
# enterpriseValue:R$ 198,10 B
# lucroAcao:R$ 0,59
# valorPatrimonialDaAcao:R$ 4,80
# disponibilidades:R$ 17,48 B
# ativoTotal:R$ 121,39 B
# dividaCp:R$ 4,12 B
# dividaLp:R$ 2,66 B
# dividaBruta:R$ 6,78 B
# dividaLiquida:- R$ 10,70 B
# patrimonioLiquido:R$ 75,53 B
# quantAcoesOrdinarias:15.735.117.965
# quantAcoesPreferenciais:0
# quantAcoesTotais:15.735.117.965
# empresa:LOJAS MARISA
# razaoSocial:MARISA LOJAS S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Comércio Varejista de Artigos Do Vestuário E Acessórios. Prestação de Serviços de Correspondente Bancário. Intermediação de Negócios E Congêneres. Atuação Como Representante de Seguros.
# acao:AMAR3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 7,30
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 18,83 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Comércio
# segmento:Tecidos. Vestuário e Calçados
# partIndices:IBRA
# precoLucro:-5,93
# precoVpa:1,66
# precoReceitaLiquida:0,78
# precoFco:103,57
# precoFcf:-1.734,94
# precoAtivoTotal:0,61
# precoEbit:-11,30
# precoCapitalGiro:3,81
# precoNcav:-3,82
# evEbit:-17,60
# evEbitda:20,78
# evReceitaLiquida:1,22
# evFco:161,34
# evFcf:-2.702,63
# evAtivoTotal:0,95
# receitaLiquida:R$ 2,43 B
# resultadoBruto:R$ 1,03 B
# ebit:- R$ 169,09 M
# depreAmort:R$ 312,27 M
# ebitda:R$ 143,18 M
# lucroLiquido:- R$ 322,03 M
# receitaLiquida:R$ 277,06 M
# resultadoBruto:R$ 52,66 M
# ebit:- R$ 149,17 M
# lucroLiquido:- R$ 171,70 M
# menorPreco52Sem:R$ 3,75
# maiorPreco52Sem:R$ 15,28
# variacao2020:-45,77%
# variacao1Ano:-33,64%
# variacao2AnosTotal:55,32%
# variacao2AnosAnual:24,66%
# variacao3AnosTotal:-16,67%
# variacao3AnosAnual:-5,90%
# variacao4AnosTotal:-0,41%
# variacao4AnosAnual:-0,10%
# variacao5AnosTotal:7,83%
# variacao5AnosAnual:1,52%
# volumeDiarioMedio3Meses:R$ 34,73 M
# retornoSobreCapitalTangivel:-8,01%
# retornoSobreCapitalInvestido:-6,60%
# retornoSobrePatrimonioLiquido:-31,28%
# retornoSobreAtivo:-9,61%
# margemBruta:42,43%
# margemLiquida:-13,23%
# margemEbit:-6,95%
# dividendYield:0,00%
# giroDoAtivo:0,73
# alavancagemFinanceira:3,26
# passivoPatrimonioLiquido:2,26
# marketCap:R$ 1,91 B
# enterpriseValue:R$ 2,98 B
# lucroAcao:- R$ 1,23
# valorPatrimonialDaAcao:R$ 4,41
# disponibilidades:R$ 308,89 M
# ativoTotal:R$ 3,15 B
# dividaCp:R$ 556,76 M
# dividaLp:R$ 817,55 M
# dividaBruta:R$ 1,37 B
# dividaLiquida:R$ 1,07 B
# patrimonioLiquido:R$ 1,15 B
# quantAcoesOrdinarias:261.666.739
# quantAcoesPreferenciais:0
# quantAcoesTotais:261.666.739
# empresa:LOJAS MARISA
# razaoSocial:MARISA LOJAS S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Comércio Varejista de Artigos Do Vestuário E Acessórios. Prestação de Serviços de Correspondente Bancário. Intermediação de Negócios E Congêneres. Atuação Como Representante de Seguros.
# acao:AMAR3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 7,30
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 18,83 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Comércio
# segmento:Tecidos. Vestuário e Calçados
# partIndices:IBRA
# precoLucro:-5,93
# precoVpa:1,66
# precoReceitaLiquida:0,78
# precoFco:103,57
# precoFcf:-1.734,94
# precoAtivoTotal:0,61
# precoEbit:-11,30
# precoCapitalGiro:3,81
# precoNcav:-3,82
# evEbit:-17,60
# evEbitda:20,78
# evReceitaLiquida:1,22
# evFco:161,34
# evFcf:-2.702,63
# evAtivoTotal:0,95
# receitaLiquida:R$ 2,43 B
# resultadoBruto:R$ 1,03 B
# ebit:- R$ 169,09 M
# depreAmort:R$ 312,27 M
# ebitda:R$ 143,18 M
# lucroLiquido:- R$ 322,03 M
# receitaLiquida:R$ 277,06 M
# resultadoBruto:R$ 52,66 M
# ebit:- R$ 149,17 M
# lucroLiquido:- R$ 171,70 M
# menorPreco52Sem:R$ 3,75
# maiorPreco52Sem:R$ 15,28
# variacao2020:-45,77%
# variacao1Ano:-33,64%
# variacao2AnosTotal:55,32%
# variacao2AnosAnual:24,66%
# variacao3AnosTotal:-16,67%
# variacao3AnosAnual:-5,90%
# variacao4AnosTotal:-0,41%
# variacao4AnosAnual:-0,10%
# variacao5AnosTotal:7,83%
# variacao5AnosAnual:1,52%
# volumeDiarioMedio3Meses:R$ 34,73 M
# retornoSobreCapitalTangivel:-8,01%
# retornoSobreCapitalInvestido:-6,60%
# retornoSobrePatrimonioLiquido:-31,28%
# retornoSobreAtivo:-9,61%
# margemBruta:42,43%
# margemLiquida:-13,23%
# margemEbit:-6,95%
# dividendYield:0,00%
# giroDoAtivo:0,73
# alavancagemFinanceira:3,26
# passivoPatrimonioLiquido:2,26
# marketCap:R$ 1,91 B
# enterpriseValue:R$ 2,98 B
# lucroAcao:- R$ 1,23
# valorPatrimonialDaAcao:R$ 4,41
# disponibilidades:R$ 308,89 M
# ativoTotal:R$ 3,15 B
# dividaCp:R$ 556,76 M
# dividaLp:R$ 817,55 M
# dividaBruta:R$ 1,37 B
# dividaLiquida:R$ 1,07 B
# patrimonioLiquido:R$ 1,15 B
# quantAcoesOrdinarias:261.666.739
# quantAcoesPreferenciais:0
# quantAcoesTotais:261.666.739
# empresa:ANIMA
# razaoSocial:ANIMA HOLDING S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Administração. Direta Ou Indireta. de Atividade de Instituições de 3º E 4º Graus. Educação
# profissional.
# acao:ANIM3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 28,95
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 17,77 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Diversos
# segmento:Serviços Educacionais
# partIndices:IBRA
# precoLucro:-77,56
# precoVpa:1,88
# precoReceitaLiquida:2,38
# precoFco:15,79
# precoFcf:25,15
# precoAtivoTotal:0,90
# precoEbit:30,02
# precoCapitalGiro:3,35
# precoNcav:-6,53
# evEbit:33,93
# evEbitda:14,70
# evReceitaLiquida:2,69
# evFco:17,85
# evFcf:28,43
# evAtivoTotal:1,02
# receitaLiquida:R$ 1,31 B
# resultadoBruto:R$ 622,54 M
# ebit:R$ 103,80 M
# depreAmort:R$ 135,86 M
# ebitda:R$ 239,66 M
# lucroLiquido:- R$ 40,17 M
# receitaLiquida:R$ 356,14 M
# resultadoBruto:R$ 180,30 M
# ebit:R$ 48,40 M
# lucroLiquido:R$ 9,44 M
# menorPreco52Sem:R$ 15,53
# maiorPreco52Sem:R$ 38,75
# variacao2020:-2,20%
# variacao1Ano:40,47%
# variacao2AnosTotal:81,11%
# variacao2AnosAnual:34,63%
# variacao3AnosTotal:26,59%
# variacao3AnosAnual:8,18%
# variacao4AnosTotal:110,21%
# variacao4AnosAnual:20,42%
# variacao5AnosTotal:102,89%
# variacao5AnosAnual:15,18%
# volumeDiarioMedio3Meses:R$ 16,95 M
# retornoSobreCapitalTangivel:8,52%
# retornoSobreCapitalInvestido:4,70%
# retornoSobrePatrimonioLiquido:-3,43%
# retornoSobreAtivo:-1,48%
# margemBruta:47,57%
# margemLiquida:-3,07%
# margemEbit:7,93%
# dividendYield:0,00%
# giroDoAtivo:0,48
# alavancagemFinanceira:2,31
# passivoPatrimonioLiquido:1,31
# marketCap:R$ 3,12 B
# enterpriseValue:R$ 3,52 B
# lucroAcao:- R$ 0,37
# valorPatrimonialDaAcao:R$ 15,39
# disponibilidades:R$ 793,30 M
# ativoTotal:R$ 3,45 B
# dividaCp:R$ 111,16 M
# dividaLp:R$ 1,09 B
# dividaBruta:R$ 1,20 B
# dividaLiquida:R$ 406,18 M
# patrimonioLiquido:R$ 1,66 B
# quantAcoesOrdinarias:107.622.935
# quantAcoesPreferenciais:0
# quantAcoesTotais:107.622.935
# empresa:ANIMA
# razaoSocial:ANIMA HOLDING S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Administração. Direta Ou Indireta. de Atividade de Instituições de 3º E 4º Graus. Educação
# profissional.
# acao:ANIM3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 28,95
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 17,77 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Diversos
# segmento:Serviços Educacionais
# partIndices:IBRA
# precoLucro:-77,56
# precoVpa:1,88
# precoReceitaLiquida:2,38
# precoFco:15,79
# precoFcf:25,15
# precoAtivoTotal:0,90
# precoEbit:30,02
# precoCapitalGiro:3,35
# precoNcav:-6,53
# evEbit:33,93
# evEbitda:14,70
# evReceitaLiquida:2,69
# evFco:17,85
# evFcf:28,43
# evAtivoTotal:1,02
# receitaLiquida:R$ 1,31 B
# resultadoBruto:R$ 622,54 M
# ebit:R$ 103,80 M
# depreAmort:R$ 135,86 M
# ebitda:R$ 239,66 M
# lucroLiquido:- R$ 40,17 M
# receitaLiquida:R$ 356,14 M
# resultadoBruto:R$ 180,30 M
# ebit:R$ 48,40 M
# lucroLiquido:R$ 9,44 M
# menorPreco52Sem:R$ 15,53
# maiorPreco52Sem:R$ 38,75
# variacao2020:-2,20%
# variacao1Ano:40,47%
# variacao2AnosTotal:81,11%
# variacao2AnosAnual:34,63%
# variacao3AnosTotal:26,59%
# variacao3AnosAnual:8,18%
# variacao4AnosTotal:110,21%
# variacao4AnosAnual:20,42%
# variacao5AnosTotal:102,89%
# variacao5AnosAnual:15,18%
# volumeDiarioMedio3Meses:R$ 16,95 M
# retornoSobreCapitalTangivel:8,52%
# retornoSobreCapitalInvestido:4,70%
# retornoSobrePatrimonioLiquido:-3,43%
# retornoSobreAtivo:-1,48%
# margemBruta:47,57%
# margemLiquida:-3,07%
# margemEbit:7,93%
# dividendYield:0,00%
# giroDoAtivo:0,48
# alavancagemFinanceira:2,31
# passivoPatrimonioLiquido:1,31
# marketCap:R$ 3,12 B
# enterpriseValue:R$ 3,52 B
# lucroAcao:- R$ 0,37
# valorPatrimonialDaAcao:R$ 15,39
# disponibilidades:R$ 793,30 M
# ativoTotal:R$ 3,45 B
# dividaCp:R$ 111,16 M
# dividaLp:R$ 1,09 B
# dividaBruta:R$ 1,20 B
# dividaLiquida:R$ 406,18 M
# patrimonioLiquido:R$ 1,66 B
# quantAcoesOrdinarias:107.622.935
# quantAcoesPreferenciais:0
# quantAcoesTotais:107.622.935
# empresa:AREZZO CO
# razaoSocial:AREZZO INDÚSTRIA E COMÉRCIO S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:O Principal Ramo de Atividade Da Companhia É A Industrialização E A Comercialização de Artigos de Couro E de Plástico em Geral. Incluindo Sapatos. Bolsas E Acessórios.
# acao:ARZZ3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 53,73
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 13,49 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Comércio
# segmento:Tecidos. Vestuário e Calçados
# partIndices:IBRA
# precoLucro:116,30
# precoVpa:7,30
# precoReceitaLiquida:3,40
# precoFco:44,63
# precoFcf:90,42
# precoAtivoTotal:2,82
# precoEbit:54,21
# precoCapitalGiro:6,98
# precoNcav:22,67
# evEbit:54,61
# evEbitda:28,41
# evReceitaLiquida:3,42
# evFco:44,96
# evFcf:91,08
# evAtivoTotal:2,84
# receitaLiquida:R$ 1,44 B
# resultadoBruto:R$ 671,42 M
# ebit:R$ 90,14 M
# depreAmort:R$ 83,15 M
# ebitda:R$ 173,30 M
# lucroLiquido:R$ 42,02 M
# receitaLiquida:R$ 154,44 M
# resultadoBruto:R$ 80,16 M
# ebit:- R$ 91,17 M
# lucroLiquido:- R$ 82,30 M
# menorPreco52Sem:R$ 33,03
# maiorPreco52Sem:R$ 68,50
# variacao2020:-15,93%
# variacao1Ano:-5,65%
# variacao2AnosTotal:22,62%
# variacao2AnosAnual:10,75%
# variacao3AnosTotal:8,17%
# variacao3AnosAnual:2,65%
# variacao4AnosTotal:111,22%
# variacao4AnosAnual:20,57%
# variacao5AnosTotal:190,61%
# variacao5AnosAnual:23,75%
# volumeDiarioMedio3Meses:R$ 28,90 M
# retornoSobreCapitalTangivel:11,86%
# retornoSobreCapitalInvestido:8,48%
# retornoSobrePatrimonioLiquido:6,23%
# retornoSobreAtivo:2,77%
# margemBruta:46,68%
# margemLiquida:2,92%
# margemEbit:6,27%
# dividendYield:0,51%
# giroDoAtivo:0,95
# alavancagemFinanceira:2,25
# passivoPatrimonioLiquido:1,25
# marketCap:R$ 4,89 B
# enterpriseValue:R$ 4,92 B
# lucroAcao:R$ 0,46
# valorPatrimonialDaAcao:R$ 7,36
# disponibilidades:R$ 565,62 M
# ativoTotal:R$ 1,73 B
# dividaCp:R$ 292,42 M
# dividaLp:R$ 308,92 M
# dividaBruta:R$ 601,35 M
# dividaLiquida:R$ 35,73 M
# patrimonioLiquido:R$ 669,47 M
# quantAcoesOrdinarias:90.954.280
# quantAcoesPreferenciais:0
# quantAcoesTotais:90.954.280
# empresa:AREZZO CO
# razaoSocial:AREZZO INDÚSTRIA E COMÉRCIO S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:O Principal Ramo de Atividade Da Companhia É A Industrialização E A Comercialização de Artigos de Couro E de Plástico em Geral. Incluindo Sapatos. Bolsas E Acessórios.
# acao:ARZZ3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 53,73
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 13,49 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo Cíclico
# subsetor:Comércio
# segmento:Tecidos. Vestuário e Calçados
# partIndices:IBRA
# precoLucro:116,30
# precoVpa:7,30
# precoReceitaLiquida:3,40
# precoFco:44,63
# precoFcf:90,42
# precoAtivoTotal:2,82
# precoEbit:54,21
# precoCapitalGiro:6,98
# precoNcav:22,67
# evEbit:54,61
# evEbitda:28,41
# evReceitaLiquida:3,42
# evFco:44,96
# evFcf:91,08
# evAtivoTotal:2,84
# receitaLiquida:R$ 1,44 B
# resultadoBruto:R$ 671,42 M
# ebit:R$ 90,14 M
# depreAmort:R$ 83,15 M
# ebitda:R$ 173,30 M
# lucroLiquido:R$ 42,02 M
# receitaLiquida:R$ 154,44 M
# resultadoBruto:R$ 80,16 M
# ebit:- R$ 91,17 M
# lucroLiquido:- R$ 82,30 M
# menorPreco52Sem:R$ 33,03
# maiorPreco52Sem:R$ 68,50
# variacao2020:-15,93%
# variacao1Ano:-5,65%
# variacao2AnosTotal:22,62%
# variacao2AnosAnual:10,75%
# variacao3AnosTotal:8,17%
# variacao3AnosAnual:2,65%
# variacao4AnosTotal:111,22%
# variacao4AnosAnual:20,57%
# variacao5AnosTotal:190,61%
# variacao5AnosAnual:23,75%
# volumeDiarioMedio3Meses:R$ 28,90 M
# retornoSobreCapitalTangivel:11,86%
# retornoSobreCapitalInvestido:8,48%
# retornoSobrePatrimonioLiquido:6,23%
# retornoSobreAtivo:2,77%
# margemBruta:46,68%
# margemLiquida:2,92%
# margemEbit:6,27%
# dividendYield:0,51%
# giroDoAtivo:0,95
# alavancagemFinanceira:2,25
# passivoPatrimonioLiquido:1,25
# marketCap:R$ 4,89 B
# enterpriseValue:R$ 4,92 B
# lucroAcao:R$ 0,46
# valorPatrimonialDaAcao:R$ 7,36
# disponibilidades:R$ 565,62 M
# ativoTotal:R$ 1,73 B
# dividaCp:R$ 292,42 M
# dividaLp:R$ 308,92 M
# dividaBruta:R$ 601,35 M
# dividaLiquida:R$ 35,73 M
# patrimonioLiquido:R$ 669,47 M
# quantAcoesOrdinarias:90.954.280
# quantAcoesPreferenciais:0
# quantAcoesTotais:90.954.280
# empresa:B3
# razaoSocial:B3 S.A. - BRASIL. BOLSA. BALCÃO
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Principais Atividades: Administrar Mercados Organizados de Títulos E Valores Mobiliários; Prestar Serviços de Registro. Compensação E Liquidação E de Suporte à Operações de Financiamento
# acao:B3SA3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 54,34
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 544,76 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Serviços Financeiros Diversos
# segmento:Serviços Financeiros Diversos
# partIndices:IBOVESPA
# precoLucro:33,21
# precoVpa:4,38
# precoReceitaLiquida:14,74
# precoFco:24,27
# precoFcf:25,19
# precoAtivoTotal:2,53
# precoEbit:26,28
# precoCapitalGiro:26,17
# precoNcav:-32,02
# evEbit:24,57
# evEbitda:19,81
# evReceitaLiquida:13,78
# evFco:22,69
# evFcf:23,54
# evAtivoTotal:2,37
# receitaLiquida:R$ 7,59 B
# resultadoBruto:R$ 6,92 B
# ebit:R$ 4,26 B
# depreAmort:R$ 1,02 B
# ebitda:R$ 5,28 B
# lucroLiquido:R$ 3,37 B
# receitaLiquida:R$ 1,91 B
# resultadoBruto:R$ 1,91 B
# ebit:R$ 1,18 B
# lucroLiquido:R$ 891,76 M
# menorPreco52Sem:R$ 29,48
# maiorPreco52Sem:R$ 66,49
# variacao2020:24,44%
# variacao1Ano:21,88%
# variacao2AnosTotal:139,94%
# variacao2AnosAnual:54,99%
# variacao3AnosTotal: -
# variacao3AnosAnual: -
# variacao4AnosTotal: -
# variacao4AnosAnual: -
# variacao5AnosTotal: -
# variacao5AnosAnual: -
# volumeDiarioMedio3Meses:R$ 672,88 M
# retornoSobreCapitalTangivel:-238,47%
# retornoSobreCapitalInvestido:13,43%
# retornoSobrePatrimonioLiquido:13,24%
# retornoSobreAtivo:7,99%
# margemBruta:91,19%
# margemLiquida:44,39%
# margemEbit:56,10%
# dividendYield:3,55%
# giroDoAtivo:0,18
# alavancagemFinanceira:1,66
# passivoPatrimonioLiquido:0,66
# marketCap:R$ 111,89 B
# enterpriseValue:R$ 104,60 B
# lucroAcao:R$ 1,64
# valorPatrimonialDaAcao:R$ 12,41
# disponibilidades:R$ 14,04 B
# ativoTotal:R$ 44,19 B
# dividaCp:R$ 4,00 B
# dividaLp:R$ 2,75 B
# dividaBruta:R$ 6,75 B
# dividaLiquida:- R$ 7,29 B
# patrimonioLiquido:R$ 25,56 B
# quantAcoesOrdinarias:2.059.138.490
# quantAcoesPreferenciais:0
# quantAcoesTotais:2.059.138.490
# empresa:B3
# razaoSocial:B3 S.A. - BRASIL. BOLSA. BALCÃO
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Principais Atividades: Administrar Mercados Organizados de Títulos E Valores Mobiliários; Prestar Serviços de Registro. Compensação E Liquidação E de Suporte à Operações de Financiamento
# acao:B3SA3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 54,34
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 544,76 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Serviços Financeiros Diversos
# segmento:Serviços Financeiros Diversos
# partIndices:IBOVESPA
# precoLucro:33,21
# precoVpa:4,38
# precoReceitaLiquida:14,74
# precoFco:24,27
# precoFcf:25,19
# precoAtivoTotal:2,53
# precoEbit:26,28
# precoCapitalGiro:26,17
# precoNcav:-32,02
# evEbit:24,57
# evEbitda:19,81
# evReceitaLiquida:13,78
# evFco:22,69
# evFcf:23,54
# evAtivoTotal:2,37
# receitaLiquida:R$ 7,59 B
# resultadoBruto:R$ 6,92 B
# ebit:R$ 4,26 B
# depreAmort:R$ 1,02 B
# ebitda:R$ 5,28 B
# lucroLiquido:R$ 3,37 B
# receitaLiquida:R$ 1,91 B
# resultadoBruto:R$ 1,91 B
# ebit:R$ 1,18 B
# lucroLiquido:R$ 891,76 M
# menorPreco52Sem:R$ 29,48
# maiorPreco52Sem:R$ 66,49
# variacao2020:24,44%
# variacao1Ano:21,88%
# variacao2AnosTotal:139,94%
# variacao2AnosAnual:54,99%
# variacao3AnosTotal: -
# variacao3AnosAnual: -
# variacao4AnosTotal: -
# variacao4AnosAnual: -
# variacao5AnosTotal: -
# variacao5AnosAnual: -
# volumeDiarioMedio3Meses:R$ 672,88 M
# retornoSobreCapitalTangivel:-238,47%
# retornoSobreCapitalInvestido:13,43%
# retornoSobrePatrimonioLiquido:13,24%
# retornoSobreAtivo:7,99%
# margemBruta:91,19%
# margemLiquida:44,39%
# margemEbit:56,10%
# dividendYield:3,55%
# giroDoAtivo:0,18
# alavancagemFinanceira:1,66
# passivoPatrimonioLiquido:0,66
# marketCap:R$ 111,89 B
# enterpriseValue:R$ 104,60 B
# lucroAcao:R$ 1,64
# valorPatrimonialDaAcao:R$ 12,41
# disponibilidades:R$ 14,04 B
# ativoTotal:R$ 44,19 B
# dividaCp:R$ 4,00 B
# dividaLp:R$ 2,75 B
# dividaBruta:R$ 6,75 B
# dividaLiquida:- R$ 7,29 B
# patrimonioLiquido:R$ 25,56 B
# quantAcoesOrdinarias:2.059.138.490
# quantAcoesPreferenciais:0
# quantAcoesTotais:2.059.138.490
# empresa:BRASIL
# razaoSocial:BCO BRASIL S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Banco Múltiplo
# acao:BBAS3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 30,27
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 378,03 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBOVESPA
# precoLucro:5,07
# precoVpa:0,83
# precoReceitaLiquida:0,63
# precoFco:1,53
# precoAtivoTotal:0,05
# recIntermFinanc:R$ 137,23 B
# resBrutoIntermFinanc:R$ 22,92 B
# recPrestServ:- R$ 225,49 M
# lucroLiquido:R$ 17,12 B
# recIntermFinanc:R$ 29,70 B
# resBrutoIntermFinanc:R$ 5,54 B
# recPrestServ:R$ 4,76 B
# lucroLiquido:R$ 3,16 B
# menorPreco52Sem:R$ 21,76
# maiorPreco52Sem:R$ 52,17
# variacao2020:-41,98%
# variacao1Ano:-31,44%
# variacao2AnosTotal:-15,20%
# variacao2AnosAnual:-7,93%
# variacao3AnosTotal:-7,52%
# variacao3AnosAnual:-2,57%
# variacao4AnosTotal:26,97%
# variacao4AnosAnual:6,15%
# variacao5AnosTotal:133,07%
# variacao5AnosAnual:18,42%
# volumeDiarioMedio3Meses:R$ 475,36 M
# retornoSobrePatrimonioLiquido:17,40%
# retornoSobreAtivo:1,01%
# margemBruta:16,57%
# margemLiquida:12,49%
# dividendYield:5,64%
# giroDoAtivo:0,08
# alavancagemFinanceira:17,20
# passivoPatrimonioLiquido:16,20
# marketCap:R$ 86,74 B
# lucroAcao:R$ 5,97
# valorPatrimonialDaAcao:R$ 36,65
# ativoTotal:R$ 1,78 T
# patrimonioLiquido:R$ 105,01 B
# quantAcoesOrdinarias:2.865.417.020
# quantAcoesPreferenciais:0
# quantAcoesTotais:2.865.417.020
# empresa:BRASIL
# razaoSocial:BCO BRASIL S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Banco Múltiplo
# acao:BBAS3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 30,27
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 378,03 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBOVESPA
# precoLucro:5,07
# precoVpa:0,83
# precoReceitaLiquida:0,63
# precoFco:1,53
# precoAtivoTotal:0,05
# recIntermFinanc:R$ 137,23 B
# resBrutoIntermFinanc:R$ 22,92 B
# recPrestServ:- R$ 225,49 M
# lucroLiquido:R$ 17,12 B
# recIntermFinanc:R$ 29,70 B
# resBrutoIntermFinanc:R$ 5,54 B
# recPrestServ:R$ 4,76 B
# lucroLiquido:R$ 3,16 B
# menorPreco52Sem:R$ 21,76
# maiorPreco52Sem:R$ 52,17
# variacao2020:-41,98%
# variacao1Ano:-31,44%
# variacao2AnosTotal:-15,20%
# variacao2AnosAnual:-7,93%
# variacao3AnosTotal:-7,52%
# variacao3AnosAnual:-2,57%
# variacao4AnosTotal:26,97%
# variacao4AnosAnual:6,15%
# variacao5AnosTotal:133,07%
# variacao5AnosAnual:18,42%
# volumeDiarioMedio3Meses:R$ 475,36 M
# retornoSobrePatrimonioLiquido:17,40%
# retornoSobreAtivo:1,01%
# margemBruta:16,57%
# margemLiquida:12,49%
# dividendYield:5,64%
# giroDoAtivo:0,08
# alavancagemFinanceira:17,20
# passivoPatrimonioLiquido:16,20
# marketCap:R$ 86,74 B
# lucroAcao:R$ 5,97
# valorPatrimonialDaAcao:R$ 36,65
# ativoTotal:R$ 1,78 T
# patrimonioLiquido:R$ 105,01 B
# quantAcoesOrdinarias:2.865.417.020
# quantAcoesPreferenciais:0
# quantAcoesTotais:2.865.417.020
# empresa:BRADESCO
# razaoSocial:BCO BRADESCO S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 1 de Governança Corporativa
# atividade:Prática de Operações Bancárias em Geral. Inclusive Câmbio
# acao:BBDC4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 20,33
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 476,94 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBOVESPA
# precoLucro:11,13
# precoVpa:1,33
# precoReceitaLiquida:1,34
# precoFco:2,18
# precoAtivoTotal:0,14
# recIntermFinanc:R$ 107,16 B
# resBrutoIntermFinanc:R$ 17,02 B
# recPrestServ:R$ 27,11 B
# lucroLiquido:R$ 16,20 B
# recIntermFinanc:R$ 18,28 B
# resBrutoIntermFinanc:- R$ 1,31 B
# recPrestServ:R$ 4,73 B
# lucroLiquido:R$ 3,51 B
# menorPreco52Sem:R$ 15,97
# maiorPreco52Sem:R$ 33,80
# variacao2020:-39,83%
# variacao1Ano:-32,09%
# variacao2AnosTotal:-10,61%
# variacao2AnosAnual:-5,46%
# variacao3AnosTotal:-7,73%
# variacao3AnosAnual:-2,65%
# variacao4AnosTotal:5,76%
# variacao4AnosAnual:1,41%
# variacao5AnosTotal:85,32%
# variacao5AnosAnual:13,12%
# volumeDiarioMedio3Meses:R$ 848,23 M
# retornoSobrePatrimonioLiquido:12,05%
# retornoSobreAtivo:1,32%
# margemBruta:32,87%
# margemLiquida:12,06%
# dividendYield:8,40%
# giroDoAtivo:0,11
# alavancagemFinanceira:9,16
# passivoPatrimonioLiquido:8,16
# marketCap:R$ 172,92 B
# lucroAcao:R$ 1,83
# valorPatrimonialDaAcao:R$ 15,23
# ativoTotal:R$ 1,33 T
# patrimonioLiquido:R$ 135,13 B
# quantAcoesOrdinarias:4.435.106.575
# quantAcoesPreferenciais:4.435.106.111
# quantAcoesTotais:8.870.212.686
# empresa:BRADESCO
# razaoSocial:BCO BRADESCO S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 1 de Governança Corporativa
# atividade:Prática de Operações Bancárias em Geral. Inclusive Câmbio
# acao:BBDC4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 20,33
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 476,94 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBOVESPA
# precoLucro:11,13
# precoVpa:1,33
# precoReceitaLiquida:1,34
# precoFco:2,18
# precoAtivoTotal:0,14
# recIntermFinanc:R$ 107,16 B
# resBrutoIntermFinanc:R$ 17,02 B
# recPrestServ:R$ 27,11 B
# lucroLiquido:R$ 16,20 B
# recIntermFinanc:R$ 18,28 B
# resBrutoIntermFinanc:- R$ 1,31 B
# recPrestServ:R$ 4,73 B
# lucroLiquido:R$ 3,51 B
# menorPreco52Sem:R$ 15,97
# maiorPreco52Sem:R$ 33,80
# variacao2020:-39,83%
# variacao1Ano:-32,09%
# variacao2AnosTotal:-10,61%
# variacao2AnosAnual:-5,46%
# variacao3AnosTotal:-7,73%
# variacao3AnosAnual:-2,65%
# variacao4AnosTotal:5,76%
# variacao4AnosAnual:1,41%
# variacao5AnosTotal:85,32%
# variacao5AnosAnual:13,12%
# volumeDiarioMedio3Meses:R$ 848,23 M
# retornoSobrePatrimonioLiquido:12,05%
# retornoSobreAtivo:1,32%
# margemBruta:32,87%
# margemLiquida:12,06%
# dividendYield:8,40%
# giroDoAtivo:0,11
# alavancagemFinanceira:9,16
# passivoPatrimonioLiquido:8,16
# marketCap:R$ 172,92 B
# lucroAcao:R$ 1,83
# valorPatrimonialDaAcao:R$ 15,23
# ativoTotal:R$ 1,33 T
# patrimonioLiquido:R$ 135,13 B
# quantAcoesOrdinarias:4.435.106.575
# quantAcoesPreferenciais:4.435.106.111
# quantAcoesTotais:8.870.212.686
# empresa:BANCO INTER
# razaoSocial:BANCO INTER S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 2 de Governança Corporativa
# atividade:Banco Múltiplo Com Carteira de Crédito. Financiamento. Investimento E Câmbio.
# acao:BIDI4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 20,16
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 23,69 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBRA
# precoLucro:634,05
# precoVpa:7,29
# precoReceitaLiquida:15,49
# precoFco:12,31
# precoAtivoTotal:1,24
# recIntermFinanc:R$ 875,24 M
# resBrutoIntermFinanc:R$ 470,73 M
# recPrestServ:R$ 119,77 M
# lucroLiquido:R$ 24,31 M
# recIntermFinanc:R$ 212,26 M
# resBrutoIntermFinanc:R$ 123,59 M
# recPrestServ:R$ 35,59 M
# lucroLiquido:R$ 299,00 mil
# menorPreco52Sem:R$ 6,87
# maiorPreco52Sem:R$ 24,22
# variacao2020:28,95%
# variacao1Ano:20,66%
# variacao2AnosTotal:212,27%
# variacao2AnosAnual:76,85%
# variacao3AnosTotal: -
# variacao3AnosAnual: -
# variacao4AnosTotal: -
# variacao4AnosAnual: -
# variacao5AnosTotal: -
# variacao5AnosAnual: -
# volumeDiarioMedio3Meses:R$ 41,21 M
# retornoSobrePatrimonioLiquido:1,57%
# retornoSobreAtivo:0,25%
# margemBruta:59,35%
# margemLiquida:2,44%
# dividendYield:0,37%
# giroDoAtivo:0,10
# alavancagemFinanceira:6,20
# passivoPatrimonioLiquido:5,20
# marketCap:R$ 15,38 B
# lucroAcao:R$ 0,03
# valorPatrimonialDaAcao:R$ 2,77
# ativoTotal:R$ 12,38 B
# patrimonioLiquido:R$ 2,12 B
# quantAcoesOrdinarias:383.452.029
# quantAcoesPreferenciais:380.992.616
# quantAcoesTotais:764.444.645
# empresa:BANCO INTER
# razaoSocial:BANCO INTER S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Nível 2 de Governança Corporativa
# atividade:Banco Múltiplo Com Carteira de Crédito. Financiamento. Investimento E Câmbio.
# acao:BIDI4
# dataCotacao:16/10/2020
# tipoDeAcao:PN
# ultimoFechamento:R$ 20,16
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 23,69 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Intermediários Financeiros
# segmento:Bancos
# partIndices:IBRA
# precoLucro:634,05
# precoVpa:7,29
# precoReceitaLiquida:15,49
# precoFco:12,31
# precoAtivoTotal:1,24
# recIntermFinanc:R$ 875,24 M
# resBrutoIntermFinanc:R$ 470,73 M
# recPrestServ:R$ 119,77 M
# lucroLiquido:R$ 24,31 M
# recIntermFinanc:R$ 212,26 M
# resBrutoIntermFinanc:R$ 123,59 M
# recPrestServ:R$ 35,59 M
# lucroLiquido:R$ 299,00 mil
# menorPreco52Sem:R$ 6,87
# maiorPreco52Sem:R$ 24,22
# variacao2020:28,95%
# variacao1Ano:20,66%
# variacao2AnosTotal:212,27%
# variacao2AnosAnual:76,85%
# variacao3AnosTotal: -
# variacao3AnosAnual: -
# variacao4AnosTotal: -
# variacao4AnosAnual: -
# variacao5AnosTotal: -
# variacao5AnosAnual: -
# volumeDiarioMedio3Meses:R$ 41,21 M
# retornoSobrePatrimonioLiquido:1,57%
# retornoSobreAtivo:0,25%
# margemBruta:59,35%
# margemLiquida:2,44%
# dividendYield:0,37%
# giroDoAtivo:0,10
# alavancagemFinanceira:6,20
# passivoPatrimonioLiquido:5,20
# marketCap:R$ 15,38 B
# lucroAcao:R$ 0,03
# valorPatrimonialDaAcao:R$ 2,77
# ativoTotal:R$ 12,38 B
# patrimonioLiquido:R$ 2,12 B
# quantAcoesOrdinarias:383.452.029
# quantAcoesPreferenciais:380.992.616
# quantAcoesTotais:764.444.645
# empresa:BRF SA
# razaoSocial:BRF S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Holding Operacional
# acao:BRFS3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 18,73
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 169,80 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo não Cíclico
# subsetor:Alimentos Processados
# segmento:Carnes e Derivados
# partIndices:IBOVESPA
# precoLucro:12,14
# precoVpa:2,16
# precoReceitaLiquida:0,43
# precoFco:2,78
# precoFcf:4,43
# precoAtivoTotal:0,31
# precoEbit:5,06
# precoCapitalGiro:3,42
# precoNcav:-0,74
# evEbit:10,00
# evEbitda:5,64
# evReceitaLiquida:0,84
# evFco:5,50
# evFcf:8,75
# evAtivoTotal:0,61
# receitaLiquida:R$ 35,80 B
# resultadoBruto:R$ 8,70 B
# ebit:R$ 3,01 B
# depreAmort:R$ 2,32 B
# ebitda:R$ 5,33 B
# lucroLiquido:R$ 1,25 B
# receitaLiquida:R$ 9,10 B
# resultadoBruto:R$ 1,98 B
# ebit:R$ 587,19 M
# lucroLiquido:R$ 307,13 M
# menorPreco52Sem:R$ 13,01
# maiorPreco52Sem:R$ 37,75
# variacao2020:-47,80%
# variacao1Ano:-48,19%
# variacao2AnosTotal:-7,32%
# variacao2AnosAnual:-3,74%
# variacao3AnosTotal:-58,84%
# variacao3AnosAnual:-25,63%
# variacao4AnosTotal:-65,49%
# variacao4AnosAnual:-23,37%
# variacao5AnosTotal:-71,39%
# variacao5AnosAnual:-22,12%
# volumeDiarioMedio3Meses:R$ 211,11 M
# retornoSobreCapitalTangivel:14,22%
# retornoSobreCapitalInvestido:10,00%
# retornoSobrePatrimonioLiquido:17,30%
# retornoSobreAtivo:2,75%
# margemBruta:24,30%
# margemLiquida:3,50%
# margemEbit:8,40%
# dividendYield:0,00%
# giroDoAtivo:0,79
# alavancagemFinanceira:6,28
# passivoPatrimonioLiquido:5,28
# marketCap:R$ 15,22 B
# enterpriseValue:R$ 30,07 B
# lucroAcao:R$ 1,54
# valorPatrimonialDaAcao:R$ 8,67
# disponibilidades:R$ 10,01 B
# ativoTotal:R$ 48,91 B
# dividaCp:R$ 4,07 B
# dividaLp:R$ 20,79 B
# dividaBruta:R$ 24,86 B
# dividaLiquida:R$ 14,86 B
# patrimonioLiquido:R$ 7,05 B
# quantAcoesOrdinarias:812.473.246
# quantAcoesPreferenciais:0
# quantAcoesTotais:812.473.246
# empresa:BRF SA
# razaoSocial:BRF S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Holding Operacional
# acao:BRFS3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 18,73
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 169,80 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Consumo não Cíclico
# subsetor:Alimentos Processados
# segmento:Carnes e Derivados
# partIndices:IBOVESPA
# precoLucro:12,14
# precoVpa:2,16
# precoReceitaLiquida:0,43
# precoFco:2,78
# precoFcf:4,43
# precoAtivoTotal:0,31
# precoEbit:5,06
# precoCapitalGiro:3,42
# precoNcav:-0,74
# evEbit:10,00
# evEbitda:5,64
# evReceitaLiquida:0,84
# evFco:5,50
# evFcf:8,75
# evAtivoTotal:0,61
# receitaLiquida:R$ 35,80 B
# resultadoBruto:R$ 8,70 B
# ebit:R$ 3,01 B
# depreAmort:R$ 2,32 B
# ebitda:R$ 5,33 B
# lucroLiquido:R$ 1,25 B
# receitaLiquida:R$ 9,10 B
# resultadoBruto:R$ 1,98 B
# ebit:R$ 587,19 M
# lucroLiquido:R$ 307,13 M
# menorPreco52Sem:R$ 13,01
# maiorPreco52Sem:R$ 37,75
# variacao2020:-47,80%
# variacao1Ano:-48,19%
# variacao2AnosTotal:-7,32%
# variacao2AnosAnual:-3,74%
# variacao3AnosTotal:-58,84%
# variacao3AnosAnual:-25,63%
# variacao4AnosTotal:-65,49%
# variacao4AnosAnual:-23,37%
# variacao5AnosTotal:-71,39%
# variacao5AnosAnual:-22,12%
# volumeDiarioMedio3Meses:R$ 211,11 M
# retornoSobreCapitalTangivel:14,22%
# retornoSobreCapitalInvestido:10,00%
# retornoSobrePatrimonioLiquido:17,30%
# retornoSobreAtivo:2,75%
# margemBruta:24,30%
# margemLiquida:3,50%
# margemEbit:8,40%
# dividendYield:0,00%
# giroDoAtivo:0,79
# alavancagemFinanceira:6,28
# passivoPatrimonioLiquido:5,28
# marketCap:R$ 15,22 B
# enterpriseValue:R$ 30,07 B
# lucroAcao:R$ 1,54
# valorPatrimonialDaAcao:R$ 8,67
# disponibilidades:R$ 10,01 B
# ativoTotal:R$ 48,91 B
# dividaCp:R$ 4,07 B
# dividaLp:R$ 20,79 B
# dividaBruta:R$ 24,86 B
# dividaLiquida:R$ 14,86 B
# patrimonioLiquido:R$ 7,05 B
# quantAcoesOrdinarias:812.473.246
# quantAcoesPreferenciais:0
# quantAcoesTotais:812.473.246
# empresa:BR PROPERT
# razaoSocial:BR PROPERTIES S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Compra. Venda E Incorp. de Imóveis Comerciais Prontos Ou A Construir; Admin de Imóveis Próprios Ou de Terceiros; Arrendamento. Exploração Com. Locação Sub-locação de Imóveis Comerciais Própr. E Outros
# acao:BRPR3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 9,05
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 16,53 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Exploração de Imóveis
# segmento:Exploração de Imóveis
# partIndices:IBRA
# precoLucro:9,74
# precoVpa:0,62
# precoReceitaLiquida:13,31
# precoFco:24,45
# precoFcf:25,09
# precoAtivoTotal:0,45
# precoEbit:5,90
# precoCapitalGiro:3,28
# precoNcav:-3,61
# evEbit:6,57
# evEbitda:6,57
# evReceitaLiquida:14,81
# evFco:27,22
# evFcf:27,93
# evAtivoTotal:0,50
# receitaLiquida:R$ 334,29 M
# resultadoBruto:R$ 334,29 M
# ebit:R$ 753,87 M
# depreAmort:R$ 0,00
# ebitda:R$ 753,87 M
# lucroLiquido:R$ 456,49 M
# receitaLiquida:R$ 75,47 M
# resultadoBruto:R$ 75,47 M
# ebit:R$ 52,28 M
# lucroLiquido:R$ 19,95 M
# menorPreco52Sem:R$ 7,50
# maiorPreco52Sem:R$ 16,30
# variacao2020:-37,82%
# variacao1Ano:-30,23%
# variacao2AnosTotal:36,42%
# variacao2AnosAnual:16,83%
# variacao3AnosTotal:-19,04%
# variacao3AnosAnual:-6,80%
# variacao4AnosTotal:9,42%
# variacao4AnosAnual:2,28%
# variacao5AnosTotal:7,53%
# variacao5AnosAnual:1,46%
# volumeDiarioMedio3Meses:R$ 22,31 M
# retornoSobreCapitalTangivel:9,28%
# retornoSobreCapitalInvestido:8,75%
# retornoSobrePatrimonioLiquido:7,06%
# retornoSobreAtivo:4,68%
# margemBruta:100,00%
# margemLiquida:136,56%
# margemEbit:225,52%
# dividendYield:0,95%
# giroDoAtivo:0,03
# alavancagemFinanceira:1,51
# passivoPatrimonioLiquido:0,51
# marketCap:R$ 4,45 B
# enterpriseValue:R$ 4,95 B
# lucroAcao:R$ 0,93
# valorPatrimonialDaAcao:R$ 14,58
# disponibilidades:R$ 1,26 B
# ativoTotal:R$ 9,92 B
# dividaCp:R$ 120,89 M
# dividaLp:R$ 1,64 B
# dividaBruta:R$ 1,76 B
# dividaLiquida:R$ 503,91 M
# patrimonioLiquido:R$ 7,17 B
# quantAcoesOrdinarias:491.510.283
# quantAcoesPreferenciais:0
# quantAcoesTotais:491.510.283
# empresa:BR PROPERT
# razaoSocial:BR PROPERTIES S.A.
# situacaoRegistro:ATIVO
# situacaoEmissor:FASE OPERACIONAL
# segmentoDeListagem:Novo Mercado
# atividade:Compra. Venda E Incorp. de Imóveis Comerciais Prontos Ou A Construir; Admin de Imóveis Próprios Ou de Terceiros; Arrendamento. Exploração Com. Locação Sub-locação de Imóveis Comerciais Própr. E Outros
# acao:BRPR3
# dataCotacao:16/10/2020
# tipoDeAcao:ON
# ultimoFechamento:R$ 9,05
# fatorDeCotacao:1 ação
# volumeFinanceiro:R$ 16,53 M
# ultimoDemonstrativo:ITR - 30/06/2020
# setor:Financeiro
# subsetor:Exploração de Imóveis
# segmento:Exploração de Imóveis
# partIndices:IBRA
# precoLucro:9,74
# precoVpa:0,62
# precoReceitaLiquida:13,31
# precoFco:24,45
# precoFcf:25,09
# precoAtivoTotal:0,45
# precoEbit:5,90
# precoCapitalGiro:3,28
# precoNcav:-3,61
# evEbit:6,57
# evEbitda:6,57
# evReceitaLiquida:14,81
# evFco:27,22
# evFcf:27,93
# evAtivoTotal:0,50
# receitaLiquida:R$ 334,29 M
# resultadoBruto:R$ 334,29 M
# ebit:R$ 753,87 M
# depreAmort:R$ 0,00
# ebitda:R$ 753,87 M
# lucroLiquido:R$ 456,49 M
# receitaLiquida:R$ 75,47 M
# resultadoBruto:R$ 75,47 M
# ebit:R$ 52,28 M
# lucroLiquido:R$ 19,95 M
# menorPreco52Sem:R$ 7,50
# maiorPreco52Sem:R$ 16,30
# variacao2020:-37,82%
# variacao1Ano:-30,23%
# variacao2AnosTotal:36,42%
# variacao2AnosAnual:16,83%
# variacao3AnosTotal:-19,04%
# variacao3AnosAnual:-6,80%
# variacao4AnosTotal:9,42%
# variacao4AnosAnual:2,28%
# variacao5AnosTotal:7,53%
# variacao5AnosAnual:1,46%
# volumeDiarioMedio3Meses:R$ 22,31 M
# retornoSobreCapitalTangivel:9,28%
# retornoSobreCapitalInvestido:8,75%
# retornoSobrePatrimonioLiquido:7,06%
# retornoSobreAtivo:4,68%
# margemBruta:100,00%
# margemLiquida:136,56%
# margemEbit:225,52%
# dividendYield:0,95%
# giroDoAtivo:0,03
# alavancagemFinanceira:1,51
# passivoPatrimonioLiquido:0,51
# marketCap:R$ 4,45 B
# enterpriseValue:R$ 4,95 B
# lucroAcao:R$ 0,93
# valorPatrimonialDaAcao:R$ 14,58
# disponibilidades:R$ 1,26 B
# ativoTotal:R$ 9,92 B
# dividaCp:R$ 120,89 M
# dividaLp:R$ 1,64 B
# dividaBruta:R$ 1,76 B
# dividaLiquida:R$ 503,91 M
# patrimonioLiquido:R$ 7,17 B
# quantAcoesOrdinarias:491.510.283
# quantAcoesPreferenciais:0
# quantAcoesTotais:491.510.283

# %%
#ativos = sht_ativos.range("A2:A"+str(last_line)).value
total_DataFrame.to_excel("output20201017.xlsx")

# %%
current = xw.apps.keys()

# %%
current

# %%
Extrato 59448 OUT 2003 a AGO 20

# %%
#ativos = [ativo + ".SA" for ativo in ativos]

# %%
# data = yf.download(  # or pdr.get_data_yahoo(...
#         # tickers list or string as well
#         tickers = ativos,

#         # use "period" instead of start/end
#         # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#         # (optional, default is '1mo')
#         period = "1d",

#         # fetch data by interval (including intraday if period < 60 days)
#         # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#         # (optional, default is '1d')
#         interval = "1d",

#         # group by ticker (to access via data['SPY'])
#         # (optional, default is 'column')
#         group_by = 'ticker',

#         # adjust all OHLC automatically
#         # (optional, default is False)
#         auto_adjust = True,

#         # download pre/post regular market hours data
#         # (optional, default is False)
#         prepost = True,

#         # use threads for mass downloading? (True/False/Integer)
#         # (optional, default is True)
#         threads = True,

#         # proxy URL scheme use use when downloading?
#         # (optional, default is None)
#         proxy = None
#     )

# %%
# data

# %%
# yf.Ticker("ABEV3.SA").history().tail(1)['Close'].iloc[0]
